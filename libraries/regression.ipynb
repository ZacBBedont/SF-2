# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

grades_df = pd.read_csv("Student_Grades.csv")
grades_df
# Out:
#     Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0     2.5       0.5       0.0      2.0        2.3    21.0     C
# 1     5.1       1.5       0.5      4.0        4.9    47.0     B
# 2     3.2       1.0       0.5      3.0        2.9    27.0     C
# 3     8.5       3.7       1.2      7.0        7.7    75.0     A
# 4     3.5       1.2       0.3      3.0        3.2    30.0     C
# 5     1.5       0.2       0.0      2.0        2.2    20.0     C
# 6     9.2       4.8       3.0      8.0        9.0    88.0     A
# 7     5.5       3.2       2.0      6.0        6.2    60.0     B
# 8     8.3       5.1       3.5      8.0        8.3    81.0     A
# 9     2.7       1.5       0.0      3.0        2.7    25.0     C
# 10    7.7       4.9       4.5      8.0        8.7    85.0     A
# 11    5.9       3.1       2.1      6.0        6.4    62.0     A
# 12    4.5       2.8       1.0      4.0        4.3    41.0     B
# 13    3.3       2.2       1.1      4.0        4.4    42.0     B
# ...

# %%
new_df = grades_df.replace(np.nan, "some value")
new_df
# Out:
#          Hours    Practice    TeamWork     MidTerm   FinalExam      Scores  \
# 0          2.5         0.5         0.0         2.0         2.3        21.0
# 1          5.1         1.5         0.5         4.0         4.9        47.0
# 2          3.2         1.0         0.5         3.0         2.9        27.0
# 3          8.5         3.7         1.2         7.0         7.7        75.0
# 4          3.5         1.2         0.3         3.0         3.2        30.0
# 5          1.5         0.2         0.0         2.0         2.2        20.0
# 6          9.2         4.8         3.0         8.0         9.0        88.0
# 7          5.5         3.2         2.0         6.0         6.2        60.0
# 8          8.3         5.1         3.5         8.0         8.3        81.0
# 9          2.7         1.5         0.0         3.0         2.7        25.0
# 10         7.7         4.9         4.5         8.0         8.7        85.0
# ...

# %%
#grades_df.replace(np.nan, "some value", inplace= True) #inplace tells it to change the csv file
#grades_df.to_csv("Student_Grades.csv",index = False) # writes the change

# %%
grades_df = grades_df.dropna()
xpoints = grades_df["Hours"].to_numpy()
ypoints = grades_df["Scores"].to_numpy()

plt.scatter(xpoints,ypoints, s = 5)
plt.xlabel("hours dedicated to studying")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %%
grades_df[grades_df["Grade"].str.contains("A")]
# Out:
#     Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 3     8.5       3.7       1.2      7.0        7.7    75.0     A
# 6     9.2       4.8       3.0      8.0        9.0    88.0     A
# 8     8.3       5.1       3.5      8.0        8.3    81.0     A
# 10    7.7       4.9       4.5      8.0        8.7    85.0     A
# 11    5.9       3.1       2.1      6.0        6.4    62.0     A
# 15    8.9       6.2       6.0      9.0        9.7    95.0     A
# 18    6.1       2.0       3.2      6.0        6.9    67.0     A
# 19    7.4       2.5       3.0      7.0        7.1    69.0     A
# 23    6.9       5.1       3.8      7.0        7.8    76.0     A
# 24    7.8       5.8       4.5      8.0        8.8    86.0     A

# %%
grades_df["MidTerm"].min()
grades_df["FinalExam"].max()
grades_df["FinalExam"].describe()
# Out:
# count    25.000000
# mean      5.348000
# std       2.528689
# min       1.900000
# 25%       3.200000
# 50%       4.900000
# 75%       7.700000
# max       9.700000
# Name: FinalExam, dtype: float64

# %%
#grades_df["Hours"] = grades_df["Hours"].astype(str)
another_df = grades_df.set_index("Hours").sort_values("Hours")
another_df.loc[1.1:5.5]

next_df = grades_df.rename(columns= {"Hours": "Hours studied"})
another_df = grades_df.rename_axis("Hours studied")
another_df
# Out:
#                Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# Hours studied
# 0                2.5       0.5       0.0      2.0        2.3    21.0     C
# 1                5.1       1.5       0.5      4.0        4.9    47.0     B
# 2                3.2       1.0       0.5      3.0        2.9    27.0     C
# 3                8.5       3.7       1.2      7.0        7.7    75.0     A
# 4                3.5       1.2       0.3      3.0        3.2    30.0     C
# 5                1.5       0.2       0.0      2.0        2.2    20.0     C
# 6                9.2       4.8       3.0      8.0        9.0    88.0     A
# 7                5.5       3.2       2.0      6.0        6.2    60.0     B
# 8                8.3       5.1       3.5      8.0        8.3    81.0     A
# 9                2.7       1.5       0.0      3.0        2.7    25.0     C
# 10               7.7       4.9       4.5      8.0        8.7    85.0     A
# ...

# %%
lst = grades_df.index[grades_df["Hours"] == 2.5].tolist()
lst
index = lst[1]

grades_df.iloc[index]
grades_df.iloc[index:index+6]
# Out:
#     Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 16    2.5       1.6       1.0      3.0        3.2    30.0     C
# 17    1.9       0.9       0.5      2.0        2.6    24.0     C
# 18    6.1       2.0       3.2      6.0        6.9    67.0     A
# 19    7.4       2.5       3.0      7.0        7.1    69.0     A
# 20    2.7       3.0       1.2      3.0        3.2    30.0     C
# 21    4.8       2.9       2.1      5.0        5.6    54.0     B

# %%
another_df = grades_df.set_index("Hours").sort_values("Hours")
another_df.loc[1.1:2,["MidTerm", "FinalExam","Grade"]]
grades_df.iloc[[0,5],0:4]
another_df.at[1.1, "FinalExam"]
grades_df.iat[2,4]
# Out:
# np.float64(2.9)

# %% [markdown]
# - write a snippet of python code that goes through the values of column "Score" and determines the minimum score

# %%
min_value = 100
for x in grades_df["Scores"]:
    if x < min_value:
        min_value = x
print(min_value)

min_value = 100
for x in range(len(grades_df["Scores"])):
    if grades_df.at[x, "Scores"] < min_value:
        min_value = grades_df.at[x,"Scores"]
print(min_value)
# Out:
# 17.0
# 17.0

# %% [markdown]
# # Regression Fit

# %%
plt.scatter(xpoints,ypoints, s = 5)
plt.xlabel("hours dedicated to studying")
plt.ylabel("score")
plt.xlim(0,10)
plt.ylim(0,100)
#coeff = np.polyfit(xpoints,ypoints, deg = 1)
# print(coeff)
#best_fit_function = np.poly1d(coeff)
#plt.plot(xpoints,best_fit_function(xpoints),label = "regression fit",color = "red")
b,a = np.polyfit(xpoints,ypoints,deg =1)
xseq = np.linspace(5,9)
plt.plot(xseq,b*xseq+a,color = "red")
print(f"slope = {b:.2f}")
print(f"y-intercept = {a:.2f}")
# Out:
# slope = 9.78
# y-intercept = 2.48
