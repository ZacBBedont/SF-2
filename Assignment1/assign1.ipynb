# %% [markdown]
# **420-SF2-RE: DS & OOP**
#
# **February 12, 2025**

# %% [markdown]
# # Assignment #1: drag with coffee filters
#
# For this assignment you will be allowed to use everything that has been covered in class regarding data science libraries.  **Any functions not covered in class will not be allowed to be used and will receive a grade of 0**.
#
# ${\color{red}\text{You should not be making any direct changes to your .csv files.}}\\$
# ${\color{red}\text{All changes done in this assignment must be done using Python code.}}$

# %% [markdown]
# ## Part 1: experiment with single coffee filter, 10 runs
# **Part 1 DUE DATE: end of class today**
#
# **Part 1 is worth 60% of Assignment #1**
#
# **Part 1 of the assignment is an in-class assignment.  Failure to be in class will receive a grade of 0 for Part 1 of the assignment and late submissions will not be accepted.**
#
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - Late submissions of Part 1 (that is, submissions outside of class) will receive a ${\color{red}\text{late penalty}}$. Part 1 may not be submitted later than **Wendesday, February 12 ay 23:59**.
#
# #### Instructions for Part 1:

# %% [markdown]
# 1. Import all necessary libraries, such as `pandas`, `matplotlib.pyplot`, `numpy`, etc.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 2. Read  your `.csv` file that has the data of the single filter experiment into a DataFrame called `df`
# 3. Display the content of the data frame to the screen

# %%
df = pd.read_csv("one_filter_10x.csv")
df
# Out:
#      Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0               0.00                 1.46                    NaN
# 1               0.02                 1.46                   0.00
# 2               0.04                 1.46                   0.05
# 3               0.06                 1.46                   0.06
# 4               0.08                 1.47                   0.01
# ..               ...                  ...                    ...
# 192             3.84                 1.13                   0.01
# 193             3.86                 1.12                   0.09
# 194             3.88                 1.13                   0.00
# 195             3.90                 1.13                  -0.17
# 196             3.92                 1.12                    NaN
#
#      Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                           NaN             0.00                 1.27
# 1                           NaN             0.02                 1.27
# 2                          1.65             0.04                 1.27
# 3                         -0.20             0.06                 1.26
# 4                         -0.67             0.08                 1.28
# ..                          ...              ...                  ...
# 192                       59.69              NaN                  NaN
# 193                       -1.46              NaN                  NaN
# 194                         NaN              NaN                  NaN
# 195                         NaN              NaN                  NaN
# 196                         NaN              NaN                  NaN
#
#      Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                      NaN                         NaN             0.00
# 1                     0.00                         NaN             0.02
# 2                     0.09                        7.29             0.04
# 3                     0.29                        1.09             0.06
# 4                     0.23                       -5.02             0.08
# ..                     ...                         ...              ...
# 192                    NaN                         NaN              NaN
# 193                    NaN                         NaN              NaN
# 194                    NaN                         NaN              NaN
# 195                    NaN                         NaN              NaN
# 196                    NaN                         NaN              NaN
#
#      Position (m) Run #3  ...  Velocity (m/s) Run #9  \
# 0                   1.29  ...                    NaN
# 1                   1.29  ...                  -6.71
# 2                   1.29  ...                  -4.86
# 3                   1.29  ...                  -2.63
# 4                   1.29  ...                   0.03
# ..                   ...  ...                    ...
# 192                  NaN  ...                    NaN
# 193                  NaN  ...                    NaN
# 194                  NaN  ...                    NaN
# 195                  NaN  ...                    NaN
# 196                  NaN  ...                    NaN
#
#      Acceleration (m/s²) Run #9  Time (s) Run #Extra  Position (m) Run #Extra  \
# 0                           NaN                 0.00                     1.45
# 1                           NaN                 0.02                     1.11
# 2                        102.07                 0.04                     1.39
# 3                         96.73                 0.06                     1.39
# 4                         62.51                 0.08                     1.39
# ..                          ...                  ...                      ...
# 192                         NaN                  NaN                      NaN
# 193                         NaN                  NaN                      NaN
# 194                         NaN                  NaN                      NaN
# 195                         NaN                  NaN                      NaN
# 196                         NaN                  NaN                      NaN
#
#      Velocity (m/s) Run #Extra  Acceleration (m/s²) Run #Extra  \
# 0                          NaN                             NaN
# 1                        -1.50                             NaN
# 2                         1.91                           98.13
# 3                         2.42                           -2.99
# 4                         0.05                          -32.88
# ..                         ...                             ...
# 192                        NaN                             NaN
# 193                        NaN                             NaN
# 194                        NaN                             NaN
# 195                        NaN                             NaN
# 196                        NaN                             NaN
#
#      Time (s) Run #10  Position (m) Run #10  Velocity (m/s) Run #10  \
# 0                0.00                  1.41                     NaN
# 1                0.02                  1.41                   -0.01
# 2                0.04                  1.41                   -0.01
# 3                0.06                  1.41                   -0.02
# 4                0.08                  1.41                    0.04
# ..                ...                   ...                     ...
# 192               NaN                   NaN                     NaN
# 193               NaN                   NaN                     NaN
# 194               NaN                   NaN                     NaN
# 195               NaN                   NaN                     NaN
# 196               NaN                   NaN                     NaN
#
#      Acceleration (m/s²) Run #10
# 0                            NaN
# 1                            NaN
# 2                          -0.01
# 3                           1.34
# 4                           1.76
# ..                           ...
# 192                          NaN
# 193                          NaN
# 194                          NaN
# 195                          NaN
# 196                          NaN
#
# [197 rows x 44 columns]

# %% [markdown]
# 4. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.  You **should not** manually adjust the content of the `data_df` for each run.
# 5. Display the content of `data_df`

# %%
data_df = pd.DataFrame()
for i in range(0,len(df.columns),4):
    data_df[df.columns[i]] = df[df.columns[i]]
for i in range(1,len(df.columns),4):
    data_df[df.columns[i]] = df[df.columns[i]]
data_df = data_df.fillna(0)
data_df.drop(columns= ["Time (s) Run #Extra","Position (m) Run #Extra"],inplace = True)
data_df
# Out:
#      Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0               0.00             0.00             0.00             0.00
# 1               0.02             0.02             0.02             0.02
# 2               0.04             0.04             0.04             0.04
# 3               0.06             0.06             0.06             0.06
# 4               0.08             0.08             0.08             0.08
# ..               ...              ...              ...              ...
# 192             3.84             0.00             0.00             0.00
# 193             3.86             0.00             0.00             0.00
# 194             3.88             0.00             0.00             0.00
# 195             3.90             0.00             0.00             0.00
# 196             3.92             0.00             0.00             0.00
#
#      Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0               0.00             0.00             0.00             0.00
# 1               0.02             0.02             0.02             0.02
# 2               0.04             0.04             0.04             0.04
# 3               0.06             0.06             0.06             0.06
# 4               0.08             0.08             0.08             0.08
# ..               ...              ...              ...              ...
# 192             0.00             0.00             0.00             0.00
# 193             0.00             0.00             0.00             0.00
# 194             0.00             0.00             0.00             0.00
# 195             0.00             0.00             0.00             0.00
# 196             0.00             0.00             0.00             0.00
#
#      Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0               0.00              0.00                 1.46
# 1               0.02              0.02                 1.46
# 2               0.04              0.04                 1.46
# 3               0.06              0.06                 1.46
# 4               0.08              0.08                 1.47
# ..               ...               ...                  ...
# 192             0.00              0.00                 1.13
# 193             0.00              0.00                 1.12
# 194             0.00              0.00                 1.13
# 195             0.00              0.00                 1.13
# 196             0.00              0.00                 1.12
#
#      Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                   1.27                 1.29                 1.41
# 1                   1.27                 1.29                 1.41
# 2                   1.27                 1.29                 1.41
# 3                   1.26                 1.29                 1.41
# 4                   1.28                 1.29                 1.41
# ..                   ...                  ...                  ...
# 192                 0.00                 0.00                 0.00
# 193                 0.00                 0.00                 0.00
# 194                 0.00                 0.00                 0.00
# 195                 0.00                 0.00                 0.00
# 196                 0.00                 0.00                 0.00
#
#      Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                   1.38                 1.45                 1.47
# 1                   1.38                 1.46                 1.47
# 2                   1.38                 1.46                 1.47
# 3                   1.40                 1.46                 1.47
# 4                   1.39                 1.46                 1.47
# ..                   ...                  ...                  ...
# 192                 0.00                 0.00                 0.00
# 193                 0.00                 0.00                 0.00
# 194                 0.00                 0.00                 0.00
# 195                 0.00                 0.00                 0.00
# 196                 0.00                 0.00                 0.00
#
#      Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                   1.39                 1.38                  1.41
# 1                   1.39                 1.44                  1.41
# 2                   1.39                 1.11                  1.41
# 3                   1.39                 1.12                  1.41
# 4                   1.39                 1.12                  1.41
# ..                   ...                  ...                   ...
# 192                 0.00                 0.00                  0.00
# 193                 0.00                 0.00                  0.00
# 194                 0.00                 0.00                  0.00
# 195                 0.00                 0.00                  0.00
# 196                 0.00                 0.00                  0.00
#
# [197 rows x 20 columns]

# %% [markdown]
# 6. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include the curved data that transitions into a drop in position.  You should only keep about 0.5 to 1 second of the roughly constant position values before the drop of position takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
#
# 7. Store your clean data into a new DataFrame called `clean_df`.
# 8. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 9. Write this to a new .csv file called `"clean_data_single_filter.csv"`.

# %%
clean_df = pd.DataFrame()
for column_no in range(1,11):
    left_side = True
    start_index = 0
    while left_side:
        if data_df[f"Position (m) Run #{column_no}"][start_index] < (data_df[f"Position (m) Run #{column_no}"][0] -.3):
            clean_df[f"Position (m) Run #{column_no}"] = data_df[f"Position (m) Run #{column_no}"].iloc[start_index:]
            left_side = False
            end_index = start_index
        start_index += 1
    right_side = True
    while right_side:
        if df[f"Velocity (m/s) Run #{column_no}"][end_index] < 0:
            clean_df[f"Position (m) Run #{column_no}"] = clean_df[f"Position (m) Run #{column_no}"].iloc[:end_index]
            right_side = False
        end_index += 1
    clean_df.insert(column_no-1,f"Time (s) Run #{column_no}",round((data_df[f"Time (s) Run #{column_no}"]-.7),2))
clean_df.index = range(1,len(clean_df)+1)
clean_df = clean_df.replace(-0.7,np.nan)
for column_no in range(1,11):
    clean_df[f"Position (m) Run #{column_no}"] = clean_df[f"Position (m) Run #{column_no}"].dropna().reset_index(drop=True)
clean_df.to_csv("clean_data_single_filter.csv",index = False)

# %% [markdown]
# 10. Plot the data using `matplotlib` from all 10 runs as scatter plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.
# - scale the size of the points so that they are not too big.
# Note that you should automate the process of plotting the 10 graphs.
#
# 11. Take the last 0.5 to 1 second of the x-values in your 10 runs, and draw a line of best fit on all your 10 graphs.

# %%
fig, axes = plt.subplots(figsize = (8,8))
for column_no in range(1, 11):
    axes.scatter(clean_df[f"Time (s) Run #{column_no}"],clean_df[f"Position (m) Run #{column_no}"],label=f"Run #{column_no}")
    b,a = np.polyfit(clean_df[f"Time (s) Run #{column_no}"][:34],clean_df[f"Position (m) Run #{column_no}"][:34],deg =1)
    xseq = np.linspace(0.5,.66)
    plt.plot(xseq,b*xseq+a,color = "red")
axes.set_xlabel("Time (s)")
axes.set_ylabel("Position (m)")
axes.set_title("Position vs Time for Multiple Runs")
axes.legend()
plt.show()

# %% [markdown]
# ### ${\color{green} \text{Submit your work to moodle and git for Part 1 before moving to Part 2}}$

# %% [markdown]
# ## Part 2: experiment with multiple coffee filters, 10 runs
# **Part 2 DUE DATE: Friday, February 14 at 20:00**
#
# **Part 2 is worth 40% of Assignment #1**
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$.  Make sure to not delete or overwrite any files during your previous submissions.
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - late submissions of Part 2 will receive a grade of 0.
#
#
# #### Instructions for Part 2:

# %% [markdown]
# 1. Read  your .csv file that has the data of filters of varying mass into a DataFrame `df`.
# 3. Display the content of the DataFrame to the screen

# %%
df = pd.read_csv("ten_filters.csv")
df
# Out:
#      Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0               0.00                 1.33                    NaN
# 1               0.02                 1.33               0.020000
# 2               0.04                 1.33               0.000225
# 3               0.06                 1.33              -0.010000
# 4               0.08                 1.33              -0.020000
# ..               ...                  ...                    ...
# 192              NaN                  NaN                    NaN
# 193              NaN                  NaN                    NaN
# 194              NaN                  NaN                    NaN
# 195              NaN                  NaN                    NaN
# 196              NaN                  NaN                    NaN
#
#      Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                           NaN             0.00                 1.38
# 1                           NaN             0.02                 1.38
# 2                         -0.71             0.04                 1.38
# 3                         -0.72             0.06                 1.37
# 4                         -0.64             0.08                 1.37
# ..                          ...              ...                  ...
# 192                         NaN              NaN                  NaN
# 193                         NaN              NaN                  NaN
# 194                         NaN              NaN                  NaN
# 195                         NaN              NaN                  NaN
# 196                         NaN              NaN                  NaN
#
#      Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                      NaN                         NaN             0.00
# 1                     0.01                         NaN             0.02
# 2                    -0.06                       -2.26             0.04
# 3                    -0.08                        0.35             0.06
# 4                    -0.03                        1.80             0.08
# ..                     ...                         ...              ...
# 192                    NaN                         NaN              NaN
# 193                    NaN                         NaN              NaN
# 194                    NaN                         NaN              NaN
# 195                    NaN                         NaN              NaN
# 196                    NaN                         NaN              NaN
#
#      Position (m) Run #3  ...  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# 0                   1.46  ...          NaN          NaN          NaN
# 1                   1.46  ...          NaN          NaN          NaN
# 2                   1.46  ...          NaN          NaN          NaN
# 3                   1.46  ...          NaN          NaN          NaN
# 4                   1.47  ...          NaN          NaN          NaN
# ..                   ...  ...          ...          ...          ...
# 192                  NaN  ...          NaN          NaN          NaN
# 193                  NaN  ...          NaN          NaN          NaN
# 194                  NaN  ...          NaN          NaN          NaN
# 195                  NaN  ...          NaN          NaN          NaN
# 196                  NaN  ...          NaN          NaN          NaN
#
#      Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  Unnamed: 76  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 192          NaN          NaN          NaN          NaN          NaN
# 193          NaN          NaN          NaN          NaN          NaN
# 194          NaN          NaN          NaN          NaN          NaN
# 195          NaN          NaN          NaN          NaN          NaN
# 196          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 77  Unnamed: 78
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 192          NaN          NaN
# 193          NaN          NaN
# 194          NaN          NaN
# 195          NaN          NaN
# 196          NaN          NaN
#
# [197 rows x 79 columns]

# %% [markdown]
# 3. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.
# 4. Display the content of `data_df`

# %%
data_df = pd.DataFrame()
for i in range(0,40,4):
    data_df[df.columns[i]] = df[df.columns[i]]
for i in range(1,40,4):
    data_df[df.columns[i]] = df[df.columns[i]]
data_df = data_df.fillna(0)
data_df
# Out:
#      Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0               0.00             0.00             0.00             0.00
# 1               0.02             0.02             0.02             0.02
# 2               0.04             0.04             0.04             0.04
# 3               0.06             0.06             0.06             0.06
# 4               0.08             0.08             0.08             0.08
# ..               ...              ...              ...              ...
# 192             0.00             0.00             0.00             0.00
# 193             0.00             0.00             0.00             0.00
# 194             0.00             0.00             0.00             0.00
# 195             0.00             0.00             0.00             0.00
# 196             0.00             0.00             0.00             0.00
#
#      Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0               0.00             0.00             0.00             0.00
# 1               0.02             0.02             0.02             0.02
# 2               0.04             0.04             0.04             0.04
# 3               0.06             0.06             0.06             0.06
# 4               0.08             0.08             0.08             0.08
# ..               ...              ...              ...              ...
# 192             0.00             0.00             0.00             0.00
# 193             0.00             0.00             0.00             0.00
# 194             0.00             0.00             0.00             0.00
# 195             0.00             0.00             0.00             0.00
# 196             0.00             0.00             0.00             0.00
#
#      Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0               0.00              0.00                 1.33
# 1               0.02              0.02                 1.33
# 2               0.04              0.04                 1.33
# 3               0.06              0.06                 1.33
# 4               0.08              0.08                 1.33
# ..               ...               ...                  ...
# 192             0.00              3.84                 0.00
# 193             0.00              3.86                 0.00
# 194             0.00              3.88                 0.00
# 195             0.00              3.90                 0.00
# 196             0.00              3.92                 0.00
#
#      Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                   1.38                 1.46                 1.48
# 1                   1.38                 1.46                 1.48
# 2                   1.38                 1.46                 1.48
# 3                   1.37                 1.46                 1.48
# 4                   1.37                 1.47                 1.48
# ..                   ...                  ...                  ...
# 192                 0.00                 0.00                 0.00
# 193                 0.00                 0.00                 0.00
# 194                 0.00                 0.00                 0.00
# 195                 0.00                 0.00                 0.00
# 196                 0.00                 0.00                 0.00
#
#      Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                    1.4                 1.48                 1.51
# 1                    1.4                 1.48                 1.51
# 2                    1.4                 1.48                 1.51
# 3                    1.4                 1.48                 1.51
# 4                    1.4                 1.48                 1.51
# ..                   ...                  ...                  ...
# 192                  0.0                 0.00                 0.00
# 193                  0.0                 0.00                 0.00
# 194                  0.0                 0.00                 0.00
# 195                  0.0                 0.00                 0.00
# 196                  0.0                 0.00                 0.00
#
#      Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                    1.5                 1.55                  1.46
# 1                    1.5                 1.56                  1.46
# 2                    1.5                 1.57                  1.46
# 3                    1.5                 1.56                  1.46
# 4                    1.5                 1.59                  1.47
# ..                   ...                  ...                   ...
# 192                  0.0                 0.00                  1.13
# 193                  0.0                 0.00                  1.12
# 194                  0.0                 0.00                  1.13
# 195                  0.0                 0.00                  1.13
# 196                  0.0                 0.00                  1.12
#
# [197 rows x 20 columns]

# %% [markdown]
# 5. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include only the bit where a drop in position starts.  You should not include any constant position values before the drop of positions takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
# 6. Store your clean data into a new DataFrame called `clean_df`.
# 7. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 8. Write this to a new .csv file called `"clean_data_multiple_filter.csv"`.

# %%
clean_df = pd.DataFrame()
for x in range(1,11):
    left_side = True
    i = 0
    while left_side:
        if (df[f"Velocity (m/s) Run #{x}"][i:i+25] <= 0).all():
            clean_df[f"Position (m) Run #{x}"] = data_df[f"Position (m) Run #{x}"].iloc[i:]
            left_side = False
        i += 1
    right_side = True
    i = 1
    clean_df.index = range(1,len(clean_df)+1)
    while right_side:
        if clean_df[f"Position (m) Run #{x}"][i+1] > clean_df[f"Position (m) Run #{x}"][i] + 1:
            clean_df[f"Position (m) Run #{x}"] = clean_df[f"Position (m) Run #{x}"].iloc[:i]
            right_side = False
        i += 1
    clean_df[f"Position (m) Run #{x}"] = clean_df[f"Position (m) Run #{x}"].dropna().reset_index(drop = True)
    time_list = [round(y * 0.02, 2) for y in range(len(clean_df[f"Position (m) Run #{x}"]+1))]
    clean_df.insert(x-1,f"Time (s) Run #{x}", time_list)
clean_df.to_csv("clean_data_multiple_filter.csv",index = False)

# %% [markdown]
# 9. Plot the data from all 10 runs as line plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.

# %%
plt.figure(figsize=(8, 8))

for x in range(1, 11):
    clean_df[f"Position (m) Run #{x}"].plot(label=f"Run #{x}")

plt.xlabel("Time (s)")
plt.ylabel("Position (m)")
plt.title("Position vs Time Varying Weight Filters")
plt.legend()
plt.show()
